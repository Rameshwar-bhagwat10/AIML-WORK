# %%
def grade(avg):
    if avg>=80:
        return 'A'
    elif avg>=70:
        return 'B'
    elif avg>=60:
        return 'C'
    else:
        return 'D'

with open("data.txt","r") as file, open("output.txt","w") as out:
    for line in file:

        parts=line.strip().split()

        name=parts[0]

        marks=list(map(int,parts[1:]))

        avg=sum(marks)/len(marks)

        grade_value=grade(avg)

        out.write(f"{name} {avg:.2f} {grade_value}\n")

        print(f"Student {name} has an average of {avg:.2f} and a grade of {grade_value}")
# Out:
# Student Ram has an average of 85.00 and a grade of A
# Student Shyam has an average of 68.33 and a grade of C
# Student Amit has an average of 45.00 and a grade of D

# %%
def calculate_avg(marks):
    return sum(marks) / len(marks)


def get_grade(avg):
    if avg >= 80:
        return "A"
    elif avg >= 60:
        return "B"
    else:
        return "C"


def process_file(input_file, output_file):
    with open(input_file, "r") as file, open(output_file, "w") as out:

        for line in file:
            parts = line.strip().split()

            name = parts[0]
            marks = list(map(int, parts[1:]))

            avg = calculate_avg(marks)
            grade = get_grade(avg)

            out.write(f"{name} {avg:.2f} {grade}\n")


process_file("data.txt", "output.txt")
