# %%
nums=[1,2,3,4,5]

# %%
squares=[x*x for x in nums]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
even=[x for x in nums if x%2==0]
print(even)
# Out:
# [2, 4]

# %%
Strings=["Hello","world","python"]

# %%
str=[s.upper()  for s in Strings]
print(str)
# Out:
# ['HELLO', 'WORLD', 'PYTHON']

# %%
nums=[56,43,78,90,-12]
result=[x for x in nums if x>50]
print(result)
# Out:
# [56, 78, 90]

# %%
result=[x for x in nums]
result = [0 if x < 0 else x for x in result]
print(result)
# Out:
# [56, 43, 78, 90, 0]

# %%
words=["hello","world","python"]
result=[len(w) for w in words]
print(result)
# Out:
# [5, 5, 6]

# %%
arr=[[1,2],[3,4]]

result=[x for x in arr for x in x]
print(result)
# Out:
# [1, 2, 3, 4]

# %%
nums=[1,2,3,4,5]
result=["High" if x>3 else "Low" for x in nums]
print(result)
# Out:
# ['Low', 'Low', 'Low', 'High', 'High']

# %%
nums2=[1,2,3,4,5]
result={x:x*x for x in nums2}
print(result)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
nums = [1,2,3,4]

result = [x*2 if x % 2 == 0 else x for x in nums]

print(result)
# Out:
# [1, 4, 3, 8]
