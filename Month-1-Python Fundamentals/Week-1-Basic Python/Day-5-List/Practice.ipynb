# %%
list=[1,2,3,4,5]
print(sum(list))
print(max(list))
print(list[::-1])
# Out:
# 15
# 5
# [5, 4, 3, 2, 1]

# %%
list=[1,2,3,2,4,5,3,6]
even=[x for x in list if x%2==0]
print(even)
# Out:
# [2, 2, 4, 6]

# %%
new_list=[]

for item in list:
    if item not in new_list:
        new_list.append(item)

print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6]
