# %%
t=(1,2,3)
print(t)

s={1,2,2,3,4,5}
print(list(set(s)))

dict={
    "name":"Ram",
    "age":20
}
print(dict)
# Out:
# (1, 2, 3)
# [1, 2, 3, 4, 5]
# {'name': 'Ram', 'age': 20}

# %%
t=(1,2,3,4,5,1,2,4,1,2,3,4,5,6,7,8,9,1,2,3,4,5)

freq={}

for num in t:
    freq[num]=freq.get(num,0)+1

print(freq)
# Out:
# {1: 4, 2: 4, 3: 3, 4: 4, 5: 3, 6: 1, 7: 1, 8: 1, 9: 1}

# %%
a={1,2,3}
b={2,3,4}

print(a & b)
# Out:
# {2, 3}

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}

dict1.update(dict2)
print(dict1)  # {'a': 1, 'b': 3, 'c': 4}
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
t=("Ram","Shyam","Hari","Ram","Shyam","Ram")

freq={}

for word in t:
    freq[word]=freq.get(word,0)+1

print(freq)
# Out:
# {'Ram': 3, 'Shyam': 2, 'Hari': 1}

# %%
dict={
    "student":{"name":"Ram","marks":90},
    "student2":{"name":"Shyam","marks":85}
}

print(dict["student"]["name"])  # Output: Ram
# Out:
# Ram

# %%
d = {"a": 1, "b": 2}

print(d.get("c", 0))
# Out:
# 0
