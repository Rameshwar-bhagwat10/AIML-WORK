# %%
name=input("Enter Name: ")
age=int(input("Enter Age: "))
city=input("Enter City: ")

print(f"My name is {name}, I am {age} years old, from {city}")
# Out:
# My name is Ram, I am 20 years old, from Yeola

# %%
prediction=float(input("Enter Prediction: "))
if prediction>0.5:
    print("Positive")
else:
    print("Negative")
# Out:
# Positive

# %%
a,b,c=map(int,input("Enter Three Numbers: ").split())
print(a+b+c)
# Out:
# 6

# %%
try:
     score=int(input("Enter Your Score: "))
     print(score)
except:
    print("Invalid Input")
# Out:
# 100
