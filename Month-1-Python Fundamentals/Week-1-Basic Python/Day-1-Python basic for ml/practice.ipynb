# %% [markdown]
# # Practice of the day 1

# %%
name="Ram"
age=20
college="SCOE"
percentage=90

print(f"Hello I Am {name}, i am {age} year old, i am studying in {college} college, i secured {percentage}% in FY")
# Out:
# Hello I Am Ram, i am 20 year old, i am studying in SCOE college, i secured 90% in FY

# %%
prediction=0.76
threshold=0.5

if prediction>threshold:
    print("prediction greater than threshold")

else:
    print("prediction lower than threshold")
# Out:
# prediction greater than threshold

# %%
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
score=int(input("Enter Score: "))

if score>50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass
