# %% [markdown]
# # Python Basics for AI/ML

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Variable in python

# %%
name="Ram"
age=18

# %% [markdown]
# # Data Types in python

# %%
x=10 #integer
y=3.14 #float
z=True #boolean
w="Hello" #string

# %%
print(type(x))
print(type(y))
print(type(z))
print(type(w))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# # type conversion

# %%
age=str(x)
print(type(age))
# Out:
# <class 'str'>

# %% [markdown]
# # print function

# %%
print("Hello, Ram! Welcome to Python programming.")
# Out:
# Hello, Ram! Welcome to Python programming.

# %%
name="Ram"
age=20

print("My name is",name,"and my age is",age)

#using f-string
print(f"My name is {name} and my age is {age}")
# Out:
# My name is Ram and my age is 20
# My name is Ram and my age is 20
